# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#https://docs.sqlalchemy.org/en/latest/core/engines.html
#SET UP LOCAL CONNECTION TO DATABASE FILE
from sqlalchemy import create_engine
engine = create_engine('sqlite:///C:\\Users\\e333775\\Documents\\BA510\\final-project-team-mike-jose-trish\\docs\\csv_data\\CoursesDB.db')
import pandas as pd


#SET UP THE MEETINGS TABLE 
#pd.io.sql.execute("""DROP TABLE meetings""",engine)
pd.io.sql.execute("""CREATE TABLE IF NOT EXISTS meetings (
 term TEXT,
 crn INTEGER,
 location TEXT,
 day TEXT,
 start TEXT,
 end TEXT
)""",engine)

df = pd.read_csv('course_meetings_combined.csv').drop('Unnamed: 0',1)
df['start'] = pd.to_datetime(df['start'])
df['end'] = pd.to_datetime(df['end'])

#INSERT FOR MEETINGS TABLE. KEEPING COMMENTED OUT BECAUSE IT TAKES SO LONG
#count = 0
#for row in df.itertuples():
#    print(count)
#    pd.io.sql.execute("""INSERT INTO meetings (term,crn,location,day,start,end) VALUES ('{}',{},'{}','{}','{}','{}')""".format(row[1],row[2],row[3],row[4],row[5],row[6]),engine)
#    count = count + 1

# %%
#READ IN INSTRUCTORS AND COURSE_TITLES INFO
instructors = pd.read_excel('courses_combined.xlsx',sheetname = 'instructors')
course_titles = pd.read_excel('courses_combined.xlsx',sheetname = 'course_titles')
# Out:
# C:\Users\e333775\AppData\Local\Continuum\anaconda3_n\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
#drop/create instructors tables
pd.io.sql.execute("""DROP TABLE INSTRUCTORS""",engine)
pd.io.sql.execute("""CREATE TABLE instructors (instructor_id INTEGER, primary_instructor varchar(20))""",engine)

#drop/create course titles tables
pd.io.sql.execute("""DROP TABLE course_titles""",engine)
pd.io.sql.execute("""CREATE TABLE course_titles (course_id INTEGER, course_title varchar(100))""",engine)


#insert instructors
for row in instructors.itertuples():
    pd.io.sql.execute("""INSERT INTO instructors (instructor_id, primary_instructor) VALUES ({},'{}')""".format(row[1],row[2]),engine)

#insert course_titles 
for row in course_titles.itertuples():
    pd.io.sql.execute("""INSERT INTO course_titles (course_id, course_title) VALUES ({},'{}')""".format(row[1],row[2]),engine)

# %%
meetings = pd.read_sql('select * from meetings',engine)

# %%
courses_combined = pd.read_excel('courses_combined.xlsx',sheetname='courses_combined').drop(['meetings','timecodes'],1)

pd.io.sql.execute("""DROP TABLE courses""",engine)
pd.io.sql.execute("""CREATE TABLE  courses (term TEXT, crn INTEGER, catalog_id TEXT, section TEXT, credits Integer, title_id Integer,instructor_id Integer, cap Integer, act Integer, rem Integer)""",engine)

for row in courses_combined.itertuples():
    pd.io.sql.execute("""INSERT INTO courses (term,crn,catalog_id,section,credits,title_id,instructor_id,cap,act,rem) VALUES('{}',{},'{}','{}',{},{},{},{},{},{})""".format(row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8],row[9],row[10]),engine)

# %%
pd.io.sql.execute("""CREATE TABLE catalog (program_code TEXT, program_name TEXT, catalog_id TEXT, course_title TEXT, credits TEXT, prereqs TEXT, coreqs TEXT, fees TEXT, attributes TEXT)""",engine)

# %%
catalog_df = pd.read_csv('catalog_files_combined.csv').drop('Unnamed: 0',1)

for row in catalog_df.itertuples():
    pd.io.sql.execute("""INSERT INTO catalog (program_code,program_name,catalog_id,course_title,credits,prereqs,coreqs,fees,attributes) VALUES ('{}','{}','{}','{}','{}','{}','{}','{}','{}')""".format(row[1],row[2],row[3],row[4],row[5],row[6],row[7],row[8],row[9]),engine)

# %%
#different tables
    #meetings
    #courses
    #catalog
    #instructors
    #course_titles

pd.read_sql("""SELECT
                b.primary_instructor,
                c.course_title, 
                a.term,a.crn,
                a.catalog_id,
                a.section,
                a.credits,
                a.cap,
                a.act,
                a.rem 
                FROM courses a, instructors b, course_titles c 
                WHERE a.instructor_id = b.instructor_id 
                AND a.title_id = c.course_id""",engine)
# Out:
#             primary_instructor  \
# 0            Michael P.  Coyne
# 1            Michael P.  Coyne
# 2            Michael P.  Coyne
# 3            Rebecca I.  Bloch
# 4            Rebecca I.  Bloch
# 5            Rebecca I.  Bloch
# 6                Paul   Caster
# 7           Jo Ann   Drusbosky
# 8           Jo Ann   Drusbosky
# 9           Jo Ann   Drusbosky
# 10          Jo Ann   Drusbosky
# 11           Arleen N.  Kardos
# 12           Arleen N.  Kardos
# 13            Scott M  Brenner
# 14           Kevin C.  Cassidy
# 15            Bruce   Bradford
# 16               Milo W.  Peck
# 17               Milo W.  Peck
# 18               Milo W.  Peck
# 19               Milo W.  Peck
# 20            Stephen E.  Yost
# 21            Stephen E.  Yost
# 22           Ahmed M.  Ebrahim
# 23            Bruce   Bradford
# 24            Bruce   Bradford
# 25            Bruce   Bradford
# 26               Paul   Caster
# 27               Paul   Caster
# 28           Kathi M.  Mettler
# 29           Kathi M.  Mettler
# ...                        ...
# 15907  Alyson Margaret  Martin
# 15908   Rachael Lynne  Gorchov
# 15909     Lauren Elise  Cesiro
# 15910          Debra S.  Sauer
# 15911  Christine R.  Rodriguez
# 15912    Thomas B.  Cunningham
# 15913      Sharlene A.  McEvoy
# 15914              Qin   Zhang
# 15915              Qin   Zhang
# 15916       Margaret A.  Wills
# 15917       Shannon E.  Kelley
# 15918     Jacqueline   Rinaldi
# 15919          Sonya R.  Huber
# 15920          Sonya R.  Huber
# 15921           Nazli S.  Alan
# 15922        Thomas E.  Conine
# 15923        Thomas E.  Conine
# 15924          Yasin   Ozcelik
# 15925        Lisa A.  Mainiero
# 15926           Camelia   Micu
# 15927           Mark S.  Ligas
# 15928          Brian Q.  Torff
# 15929       Joyce Muriel  Shea
# 15930           Joachim   Kuhn
# 15931  Lucrecia   Garcia Iommi
# 15932     Margaret M.  McClure
# 15933        Erik J.  Ranstrom
# 15931                       United States Foreign Policy  Winter2018  11814
# 15932                 Abnormal Psychology for Non-Majors  Winter2018  11839
# 15933  Exploring Religion: Religion in a Comparative Key  Winter2018  11817
# 15934                        Contemporary Moral Problems  Winter2018  11831
# 15935                    Criminal Justice System Seminar  Winter2018  11819
# 15936                            Introduction to Drawing  Winter2018  11832
#
#       catalog_id section  credits  cap  act  rem
# 0        AC 0011     C01      3.0    0   31  -31
# 1        AC 0011     C02      3.0    0   31  -31
# 2        AC 0011     C03      3.0    0   31  -31
# 3        AC 0011     C04      3.0    0   29  -29
# 4        AC 0011     C05      3.0    0   30  -30
# 5        AC 0011     C06      3.0    0   31  -31
# 6        AC 0011       G      3.0   30   31   -1
# 7        AC 0011       H      3.0   30   32   -2
# 8        AC 0011       I      3.0   30   33   -3
# 9        AC 0011       J      3.0   30   32   -2
# 10       AC 0011       K      3.0   30   34   -4
# 11       AC 0011       L      3.0   30   31   -1
# 12       AC 0011       M      3.0   30   31   -1
# 13       AC 0011       N      3.0   30   26    4
# 14       AC 0011       O      3.0   30   31   -1
# 15       AC 0012       A      3.0   30   17   13
# 16       AC 0203       A      3.0   28   28    0
# 17       AC 0203       B      3.0   28   28    0
# 18       AC 0203       D      3.0   17   16    1
# 19       AC 0203       E      3.0   24   22    2
# 20       AC 0204       A      3.0   10   12   -2
# 21       AC 0204     AAA      3.0   10    1    9
# 22       AC 0310       A      3.0   24   27   -3
# 23       AC 0320       A      3.0   10   15   -5
# 24       AC 0320     AAA      3.0   10    6    4
# 25       AC 0320       B      3.0   28   27    1
# 26       AC 0330       A      3.0   25   28   -3
# 27       AC 0330       B      3.0   25   23    2
# 28       AC 0343       A      3.0   10   16   -6
# 29       AC 0343     AAA      3.0   10    7    3
# ...          ...     ...      ...  ...  ...  ...
# 15907   SE 0568A       3      3.0   16   16    0
# 15908    SA 0101       1      3.0   15   14    1
# 15909    AH 0172     OL1      3.0   20   21   -1
# 15910    BI 0070     OL1      3.0   20   10   10
# 15911    BI 0071     OL1      3.0   20   13    7
# 15912    BI 0075     OL1      3.0   24   22    2
# 15913    BU 0211       1      3.0   25   15   10
# 15914    CO 0100     OL1      3.0   20   12    8
# 15915    CO 0240     OL1      3.0   20   12    8
# 15916    CO 0246       1      3.0   15    8    7
# 15917    EN 0141     OL1      3.0   20   20    0
# 15918    EN 0163     OL1      3.0   20   16    4
# 15919   ENW 0444       1      6.0    0    1   -1
# 15920   ENW 0445       1      6.0    0    1   -1
# 15921    FI 0101     OL1      3.0   20    9   11
# 15922    FI 0500       1      3.0   16    7    9
# 15923    FI 0585      TC      3.0    0    1   -1
# 15924    IS 0500       1      3.0   25   10   15
# 15925    MG 0500       1      3.0   14   16   -2
# 15926    MK 0101     OL1      3.0   20    9   11
# 15927    MK 0535       1      3.0   20    9   11
# 15928    MU 0102       1      3.0   15   12    3
# 15929    NS 0687       1     -5.0   30    3   27
